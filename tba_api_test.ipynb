# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as mp
import seaborn as sb
import pandas as pd
import numpy as np
import requests
import math

# %%
header = {'X-TBA-Auth-Key': 'idowTJ6ZvpMVVh3IKFVMZPsuk65Tuors4lM7ueszL3QkIPznPONkyhdA3esVY1Tf',
          'accept': 'application/json'}
response = requests.get("https://www.thebluealliance.com/api/v3/team/frc6017/event/2023catt/status", headers=header)

# %%
response.json()
# Out:
# {'alliance': {'backup': None, 'name': 'Alliance 4', 'number': 4, 'pick': 3},
#  'alliance_status_str': '<b>3rd Pick</b> of <b>Alliance 4</b>',
#  'last_match_key': '2023catt_f1m3',
#  'next_match_key': None,
#  'overall_status_str': 'Team 6017 was <b>Rank 26/43</b> with a record of <b>5-4-0</b> in quals, competed in the playoffs as the <b>3rd Pick</b> of <b>Alliance 4</b>, and <b>won the event</b> with a playoff record of <b>5-1-0</b>.',
#  'playoff': {'current_level_record': {'losses': 1, 'ties': 0, 'wins': 2},
#   'level': 'f',
#   'playoff_average': None,
#   'record': {'losses': 1, 'ties': 0, 'wins': 5},
#   'status': 'won'},
#  'playoff_status_str': '<b>Won the event</b> with a playoff record of <b>5-1-0</b>',
#  'qual': {'num_teams': 43,
#   'ranking': {'dq': 0,
#    'matches_played': 9,
#    'qual_average': None,
#    'rank': 26,
#    'record': {'losses': 4, 'ties': 0, 'wins': 5},
#    'sort_orders': [1.6666666, 87.77778, 20.444445, 20.222221],
#    'team_key': 'frc6017'},
#   'sort_order_info': [{'name': 'Ranking Score', 'precision': 2},
#    {'name': 'Avg Match', 'precision': 2},
#    {'name': 'Avg Charge Station', 'precision': 2},
#    {'name': 'Avg Auto', 'precision': 2}],
#   'status': 'completed'}}

# %%
team_status_respons = pd.DataFrame.from_dict(response.json())
team_status_respons.reset_index(drop=False, inplace=True)

# %%
team_status_respons
# Out:
#                    index    alliance                   alliance_status_str  \
# 0                 backup        None  <b>3rd Pick</b> of <b>Alliance 4</b>
# 1                   name  Alliance 4  <b>3rd Pick</b> of <b>Alliance 4</b>
# 2                 number           4  <b>3rd Pick</b> of <b>Alliance 4</b>
# 3                   pick           3  <b>3rd Pick</b> of <b>Alliance 4</b>
# 4   current_level_record         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
# 5                  level         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
# 6        playoff_average         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
# 7                 record         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
# 8                 status         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
# 9              num_teams         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
# 10               ranking         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
# 11       sort_order_info         NaN  <b>3rd Pick</b> of <b>Alliance 4</b>
#
#    last_match_key next_match_key  \
# 0   2023catt_f1m3           None
# 1   2023catt_f1m3           None
# 2   2023catt_f1m3           None
# 3   2023catt_f1m3           None
# 4   2023catt_f1m3           None
# 5   2023catt_f1m3           None
# 6   2023catt_f1m3           None
# 7   2023catt_f1m3           None
# 8   2023catt_f1m3           None
# 9   2023catt_f1m3           None
# 10  2023catt_f1m3           None
# 11  2023catt_f1m3           None
#
#                                    overall_status_str  \
# 0   Team 6017 was <b>Rank 26/43</b> with a record ...
# 1   Team 6017 was <b>Rank 26/43</b> with a record ...
# 2   Team 6017 was <b>Rank 26/43</b> with a record ...
# 3   Team 6017 was <b>Rank 26/43</b> with a record ...
# 4   Team 6017 was <b>Rank 26/43</b> with a record ...
# 5   Team 6017 was <b>Rank 26/43</b> with a record ...
# 6   Team 6017 was <b>Rank 26/43</b> with a record ...
# 7   Team 6017 was <b>Rank 26/43</b> with a record ...
# 8   Team 6017 was <b>Rank 26/43</b> with a record ...
# 9   Team 6017 was <b>Rank 26/43</b> with a record ...
# 10  Team 6017 was <b>Rank 26/43</b> with a record ...
# 11  Team 6017 was <b>Rank 26/43</b> with a record ...
#
#                                 playoff  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4   {'losses': 1, 'ties': 0, 'wins': 2}
# 5                                     f
# 6                                  None
# 7   {'losses': 1, 'ties': 0, 'wins': 5}
# 8                                   won
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
#
#                                    playoff_status_str  \
# 0   <b>Won the event</b> with a playoff record of ...
# 1   <b>Won the event</b> with a playoff record of ...
# 2   <b>Won the event</b> with a playoff record of ...
# 3   <b>Won the event</b> with a playoff record of ...
# 4   <b>Won the event</b> with a playoff record of ...
# 5   <b>Won the event</b> with a playoff record of ...
# 6   <b>Won the event</b> with a playoff record of ...
# 7   <b>Won the event</b> with a playoff record of ...
# 8   <b>Won the event</b> with a playoff record of ...
# 9   <b>Won the event</b> with a playoff record of ...
# 10  <b>Won the event</b> with a playoff record of ...
# 11  <b>Won the event</b> with a playoff record of ...
#
#                                                  qual
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                           completed
# 9                                                  43
# 10  {'dq': 0, 'matches_played': 9, 'qual_average':...
# 11  [{'name': 'Ranking Score', 'precision': 2}, {'...

# %% [markdown]
# ---
# ---
# # First API
#
# ---

# %%
header = {
    "Authorization": "Basic aXZhbnkyMDA6ZjgzNTYwMjctMWE2Yy00YWU5LTliNjEtMTJkMDJjNjI1Y2Rj",
    'If-Modified-Since': ''
}

# %%
test_idk = requests.get("https://frc-api.firstinspires.org/v3.0/2022/matches/MXMO", headers=header)
final_df = pd.DataFrame.from_dict(test_idk.json())
final_df = final_df["Matches"].apply(pd.Series)
final_df[final_df["tournamentLevel"] == "None"]
# Out:
#     isReplay matchVideoLink description  matchNumber  scoreRedFinal  \
# 81     False           None  Test Match          999            NaN
#
#     scoreRedFoul  scoreRedAuto  scoreBlueFinal  scoreBlueFoul  scoreBlueAuto  \
# 81           NaN           NaN             NaN            NaN            NaN
#
#             autoStartTime actualStartTime tournamentLevel postResultTime  \
# 81  2022-03-10T18:16:48.4            None            None           None
#
#                                                 teams
# 81  [{'teamNumber': 3510, 'station': 'Red1', 'dq':...

# %%
test_idk = requests.get("https://frc-api.firstinspires.org/v3.0/2023/matches/MXMO/Qualification", headers=header)
final_df = pd.DataFrame.from_dict(test_idk.json())
final_df = final_df["Matches"].apply(pd.Series)
teams_stuff = final_df["teams"].apply(pd.Series)
final_df.drop("teams", axis=1, inplace=True)
team_list = []
for i in range(6):
    temp_team = teams_stuff[i].apply(pd.Series)
    temp_team.rename(columns={"teamNumber":i}, inplace=True)
    temp_team = temp_team[i]
    team_list.append(temp_team)
    df_team_info = pd.concat(team_list, axis=1)
final_df = pd.concat([final_df,df_team_info], axis=1)
final_df.rename(columns={0:"Red1",1:"Red2",2:"Red3",3:"Blue1",4:"Blue2",5:"Blue3"}, inplace=True)
final_df.drop(["isReplay", "matchVideoLink", "description", "autoStartTime", "actualStartTime", "tournamentLevel", "postResultTime"], axis=1, inplace=True)
final_df
# Out:
#     matchNumber  scoreRedFinal  scoreRedFoul  scoreRedAuto  scoreBlueFinal  \
# 0             1             45             0             6              58
# 1             2             71             5             3              50
# 2             3             47             0            14              56
# 3             4             17             0             3               7
# 4             5            102             0            27              57
# ..          ...            ...           ...           ...             ...
# 62           63             91            32            18              36
# 63           64             75             0            25              71
# 64           65             84             0            27              41
# 65           66             73             5             9              44
# 66           67             34             0            15              46
#
#     scoreBlueFoul  scoreBlueAuto  Red1  Red2  Red3  Blue1  Blue2  Blue3
# 0               0              6  6647  4782  6170   7421   3933   7546
# 1              10             12  6676  3794  3478   3472   6608   4584
# 2               0             17  4010  5932  6832   6017   6106   9280
# 3               5              0  8740  6694  8741   9060   3526   7725
# 4              12             19  9282  4635  2283   6348   6702   5959
# ..            ...            ...   ...   ...   ...    ...    ...    ...
# 62              0             10  5887  7725  6017   2283   8293   3794
# 63              5             13  4635  9060  9280   8256   6170   7421
# 64              0             10  9213  6647  7102   8741   6106   6702
# 65             12             18  3472  3158  5959   3526   6832   4584
# 66              0             24  5133  3933  6017   6608   6694   4775
#
# [67 rows x 13 columns]

# %%
test_idk = requests.get(f"https://frc-api.firstinspires.org/v3.0/2023/scores/MXMO/Qualification?matchNumber=2", headers=header)
final_df = pd.DataFrame.from_dict(test_idk.json())
final_df = final_df["MatchScores"].apply(pd.Series)
final_df = final_df["alliances"].apply(pd.Series)
blue_al = final_df[0].apply(pd.Series)
red_al = final_df[1].apply(pd.Series)
match_stuff = pd.concat([blue_al, red_al], axis=0)
match_stuff.reset_index(drop=True,inplace=True)
match_stuff
# Out:
#   alliance mobilityRobot1 autoChargeStationRobot1 endGameChargeStationRobot1  \
# 0     Blue            Yes                    None                     Docked
# 1      Red             No                    None                     Docked
#
#   mobilityRobot2 autoChargeStationRobot2 endGameChargeStationRobot2  \
# 0             No                    None                       None
# 1            Yes                    None                     Docked
#
#   mobilityRobot3 autoChargeStationRobot3 endGameChargeStationRobot3  ...  \
# 0             No                    None                       None  ...
# 1             No                    None                     Docked  ...
#
#   coopGamePieceCount  totalChargeStationPoints  foulCount  techFoulCount  \
# 0                  1                         6          1              0
# 1                  1                        30          2              0
#
#    g405Penalty h111Penalty  adjustPoints  foulPoints rp  totalPoints
# 0        False       False             0          10  0           50
# 1        False       False             0           5  3           71
#
# [2 rows x 41 columns]

# %%
match_stuff.columns
# Out:
# Index(['alliance', 'mobilityRobot1', 'autoChargeStationRobot1',
#        'endGameChargeStationRobot1', 'mobilityRobot2',
#        'autoChargeStationRobot2', 'endGameChargeStationRobot2',
#        'mobilityRobot3', 'autoChargeStationRobot3',
#        'endGameChargeStationRobot3', 'autoCommunity', 'autoGamePieceCount',
#        'autoMobilityPoints', 'autoPoints', 'autoDocked', 'autoBridgeState',
#        'autoGamePiecePoints', 'autoChargeStationPoints', 'teleopCommunity',
#        'teleopGamePieceCount', 'teleopPoints', 'teleopGamePiecePoints',
#        'extraGamePieceCount', 'endGameChargeStationPoints',
#        'endGameParkPoints', 'endGameBridgeState', 'links', 'linkPoints',
#        'activationBonusAchieved', 'sustainabilityBonusAchieved',
#        'coopertitionCriteriaMet', 'coopGamePieceCount',
#        'totalChargeStationPoints', 'foulCount', 'techFoulCount', 'g405Penalty',
#        'h111Penalty', 'adjustPoints', 'foulPoints', 'rp', 'totalPoints'],
#       dtype='object')

# %%
blue_al.columns
# Out:
# Index(['match_num', 'alliance', 'mobilityRobot1', 'autoChargeStationRobot1',
#        'endGameChargeStationRobot1', 'mobilityRobot2',
#        'autoChargeStationRobot2', 'endGameChargeStationRobot2',
#        'mobilityRobot3', 'autoChargeStationRobot3',
#        'endGameChargeStationRobot3', 'autoCommunity', 'autoGamePieceCount',
#        'autoMobilityPoints', 'autoPoints', 'autoDocked', 'autoBridgeState',
#        'autoGamePiecePoints', 'autoChargeStationPoints', 'teleopCommunity',
#        'teleopGamePieceCount', 'teleopPoints', 'teleopGamePiecePoints',
#        'extraGamePieceCount', 'endGameChargeStationPoints',
#        'endGameParkPoints', 'endGameBridgeState', 'links', 'linkPoints',
#        'activationBonusAchieved', 'sustainabilityBonusAchieved',
#        'coopertitionCriteriaMet', 'coopGamePieceCount',
#        'totalChargeStationPoints', 'foulCount', 'techFoulCount', 'g405Penalty',
#        'h111Penalty', 'adjustPoints', 'foulPoints', 'rp', 'totalPoints'],
#       dtype='object')
